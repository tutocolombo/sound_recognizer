# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sound_recognizer.data.esc50 import ESC50
import matplotlib.pyplot as plt
from IPython import display
import pandas as pd

from sound_recognizer.metadata.esc50 import MAPPING

map = MAPPING

# %%
esc = ESC50(args=None)

esc.setup()

# %%
sample = esc.data_train[1100]
print(map[sample[1]])
plt.imshow(sample[0].permute(1,2,0))
# display.Audio('/notebooks/data/downloaded/ESC-50-master/audio/1-100032-A-0.wav')
# Out:
# clock_tick

# %%
sample[0]
# Out:
# tensor([[[-9.8171e+00, -7.2978e+00, -5.6283e+00,  ...,  1.3303e+01,
#            1.1346e+01,  7.8319e+00],
#          [-6.4302e+01, -1.0408e+01, -4.9534e+00,  ...,  9.5757e+00,
#            4.5571e+00,  6.8023e+00],
#          [-3.7390e+01, -1.3851e+01, -1.5173e+01,  ..., -3.7955e+00,
#           -1.3832e+00, -4.7513e-02],
#          ...,
#          [-3.2263e+01, -3.1090e+01, -3.4218e+01,  ..., -3.6114e+01,
#           -3.4663e+01, -3.4854e+01],
#          [-3.4080e+01, -3.3614e+01, -3.4900e+01,  ..., -3.4260e+01,
#           -3.1109e+01, -3.1450e+01],
#          [-3.8375e+01, -3.5900e+01, -3.5803e+01,  ..., -3.4874e+01,
#           -3.4338e+01, -3.5968e+01]]])
